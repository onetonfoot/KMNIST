# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Data

# %%
from generator import fonts, Generator
import string
chars = list(string.ascii_letters)
generator = Generator(chars, fonts)

# %%
generator.make_grid(40)
# Out:
# <PIL.Image.Image image mode=RGB size=530x332 at 0x7F44D10BFB70>

# %% [markdown]
# # Augmentations

# %%
from augmentation import aug
import numpy as np
from PIL import Image

# %%
generator = Generator(chars, fonts, aug)
generator.make_grid(40)
# Out:
# <PIL.Image.Image image mode=RGB size=530x332 at 0x7F44111025C0>

# %%
generator.make_grid(400, 'c')
# Out:
# <PIL.Image.Image image mode=RGB size=530x3302 at 0x7F445FF4A8D0>
