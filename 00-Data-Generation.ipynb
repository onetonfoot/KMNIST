# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Data

# %%
from generator import fonts, Generator
import string
chars = list(string.ascii_letters)
generator = Generator(chars, fonts)

# %%
generator.make_grid(40)
# Out:
# <PIL.Image.Image image mode=RGB size=530x332 at 0x7F8EA99E5FD0>

# %%
generator.sample(10,'a')
# Out:
# ([<PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4D0B00>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4D05C0>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4D0668>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4D0550>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4D0358>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4D04A8>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4B67F0>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4B6860>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4B6668>,
#   <PIL.Image.Image image mode=RGB size=64x64 at 0x7F8E9E4B64E0>],
#  ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a'])

# %% [markdown]
# # Augmentations

# %%
from augmentation import aug

# %%
generator = Generator(chars, fonts, aug)
generator.make_grid(40)
# Out:
# <PIL.Image.Image image mode=RGB size=530x332 at 0x7F8E9EB98198>

# %%
generator.make_grid(40, 'a')
# Out:
# <PIL.Image.Image image mode=RGB size=530x332 at 0x7F8EA9990CC0>
